# %%
#@markdown Check type of GPU and VRAM available.
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15360 MiB, 15101 MiB

# %% [markdown]
# https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth

# %% [markdown]
# ## Install Requirements

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate transformers ftfy bitsandbytes==0.35.0 gradio natsort safetensors xformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 17.5 MB/s eta 0:00:00
#   Building wheel for diffusers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 KB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 95.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 76.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 78.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 MB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 84.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 KB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.1/144.1 KB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 KB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 66.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 KB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 32.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 KB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 8.4 MB/s eta 0:00:00
#   Building wheel for ffmpy (setup.py) ... done

# %%
#@title Login to HuggingFace 🤗

#@markdown You need to accept the model license before downloading or using the Stable Diffusion weights. Please, visit the [model card](https://huggingface.co/runwayml/stable-diffusion-v1-5), read the license and tick the checkbox if you agree. You have to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work.
# https://huggingface.co/settings/tokens
# !mkdir -p ~/.huggingface
HUGGINGFACE_TOKEN = "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" #@param {type:"string"}
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token

# %% [markdown]
# ## Settings and run

# %%
#@markdown If model weights should be saved directly in google drive (takes around 4-5 GB).
save_to_gdrive = False #@param {type:"boolean"}
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')

#@markdown Name/Path of the initial model.
MODEL_NAME = "stabilityai/stable-diffusion-2-1" #@param {type:"string"}

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "stable_diffusion_weights/zwx" #@param {type:"string"}
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "/content/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR
# Out:
# [*] Weights will be saved at /content/stable_diffusion_weights/zwx

# %% [markdown]
# # Start Training
#
# Use the table below to choose the best flags based on your memory and speed requirements. Tested on Tesla T4 GPU.
#
#
# | `fp16` | `train_batch_size` | `gradient_accumulation_steps` | `gradient_checkpointing` | `use_8bit_adam` | GB VRAM usage | Speed (it/s) |
# | ---- | ------------------ | ----------------------------- | ----------------------- | --------------- | ---------- | ------------ |
# | fp16 | 1                  | 1                             | TRUE                    | TRUE            | 9.92       | 0.93         |
# | no   | 1                  | 1                             | TRUE                    | TRUE            | 10.08      | 0.42         |
# | fp16 | 2                  | 1                             | TRUE                    | TRUE            | 10.4       | 0.66         |
# | fp16 | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 1.14         |
# | no   | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 0.49         |
# | fp16 | 1                  | 2                             | TRUE                    | TRUE            | 11.56      | 1            |
# | fp16 | 2                  | 1                             | FALSE                   | TRUE            | 13.67      | 0.82         |
# | fp16 | 1                  | 2                             | FALSE                   | TRUE            | 13.7       | 0.83          |
# | fp16 | 1                  | 1                             | TRUE                    | FALSE           | 15.79      | 0.77         |

# %% [markdown]
# Add `--gradient_checkpointing` flag for around 9.92 GB VRAM usage.
#
# remove `--use_8bit_adam` flag for full precision. Requires 15.79 GB with `--gradient_checkpointing` else 17.8 GB.
#
# remove `--train_text_encoder` flag to reduce memory usage further, degrades output quality.

# %%
# You can also add multiple concepts here. Try tweaking `--max_train_steps` accordingly.

concepts_list = [
#    {
#        "instance_prompt":      "photo of zwx dog",
#        "class_prompt":         "photo of a dog",
#        "instance_data_dir":    "/content/data/zwx",
#        "class_data_dir":       "/content/data/dog"
#    },
     {
         "instance_prompt":      "photo of ukj person",
         "class_prompt":         "photo of a person",
         "instance_data_dir":    "/content/data/ukj",
         "class_data_dir":       "/content/data/person"
     }
]

# `class_data_dir` contains regularization images
import json
import os
for c in concepts_list:
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)

# %%
#@markdown Upload your images by running this cell.

#@markdown OR

#@markdown You can use the file manager on the left panel to upload (drag and drop) to each `instance_data_dir` (it uploads faster). You can also upload your own class images in `class_data_dir` if u don't wanna generate with SD.

import os
from google.colab import files
import shutil

for c in concepts_list:
    print(f"Uploading instance images for `{c['instance_prompt']}`")
    uploaded = files.upload()
    for filename in uploaded.keys():
        dst_path = os.path.join(c['instance_data_dir'], filename)
        shutil.move(filename, dst_path)

# %%
# !python3 train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=50 \
  --sample_batch_size=4 \
  --max_train_steps=800 \
  --save_interval=10000 \
  --save_sample_prompt="photo of zwx dog" \
  --concepts_list="concepts_list.json"

# Reduce the `--save_interval` to lower than `--max_train_steps` to save weights from intermediate steps.
# `--save_sample_prompt` can be same as `--instance_prompt` to generate intermediate samples (saved along with weights in samples directory).
# Out:
# 2023-04-04 18:49:23.989794: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/accelerate/accelerator.py:249: FutureWarning: `logging_dir` is deprecated and will be removed in version 0.18.0 of 🤗 Accelerate. Use `project_dir` instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/huggingface_hub/utils/_hf_folder.py:92: UserWarning: A token has been found in `/root/.huggingface/token`. This is the old path where tokens were stored. The new location is `/root/.cache/huggingface/token` which is configurable using `HF_HOME` environment variable. Your token has been copied to this new location. You can now safely delete the old token file manually or use `huggingface-cli logout`.
#   warnings.warn(
# Downloading (…)lve/main/config.json: 100% 547/547 [00:00<00:00, 85.7kB/s]
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:00<00:00, 358MB/s]
# /usr/local/lib/python3.9/dist-packages/safetensors/torch.py:99: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   with safe_open(filename, framework="pt", device=device) as f:
# /usr/local/lib/python3.9/dist-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.9/dist-packages/torch/storage.py:899: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = cls(wrap_storage=untyped_storage)
# Downloading (…)p16/model_index.json: 100% 517/517 [00:00<00:00, 86.0kB/s]
# text_encoder/model.safetensors not found
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]
# Downloading pytorch_model.bin:   0% 0.00/681M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   2% 10.5M/681M [00:00<00:08, 79.0MB/s]
# Downloading pytorch_model.bin:   3% 21.0M/681M [00:00<00:07, 88.1MB/s]
# Downloading pytorch_model.bin:   5% 31.5M/681M [00:00<00:07, 88.6MB/s]
# Downloading pytorch_model.bin:   6% 41.9M/681M [00:00<00:07, 90.4MB/s]
# Downloading pytorch_model.bin:   8% 52.4M/681M [00:00<00:06, 91.2MB/s]
# Downloading pytorch_model.bin:   9% 62.9M/681M [00:00<00:06, 92.7MB/s]
# Downloading pytorch_model.bin:  11% 73.4M/681M [00:00<00:06, 92.1MB/s]
#
# Downloading (…)okenizer_config.json: 100% 819/819 [00:00<00:00, 133kB/s]
#
#
# Downloading (…)_encoder/config.json: 100% 628/628 [00:00<00:00, 99.5kB/s]
#
#
# Downloading (…)cheduler_config.json: 100% 351/351 [00:00<00:00, 53.5kB/s]
#
#
# Downloading (…)cial_tokens_map.json: 100% 460/460 [00:00<00:00, 70.4kB/s]
#
#
# Downloading (…)75a/unet/config.json:   0% 0.00/999 [00:00<?, ?B/s]
#
#
# Downloading (…)75a/unet/config.json: 100% 999/999 [00:00<00:00, 72.7kB/s]
#
#
# Fetching 12 files:  17% 2/12 [00:01<00:09,  1.04it/s]
# Downloading pytorch_model.bin:  12% 83.9M/681M [00:00<00:07, 83.1MB/s]
# Downloading pytorch_model.bin:  15% 105M/681M [00:01<00:06, 91.9MB/s]
# Downloading pytorch_model.bin:  17% 115M/681M [00:01<00:06, 89.8MB/s]
# Downloading pytorch_model.bin:  18% 126M/681M [00:01<00:06, 87.5MB/s]
# Downloading pytorch_model.bin:  20% 136M/681M [00:01<00:06, 88.7MB/s]
# Downloading pytorch_model.bin:  22% 147M/681M [00:01<00:06, 88.3MB/s]
# Downloading pytorch_model.bin:  23% 157M/681M [00:01<00:05, 89.9MB/s]
# Downloading pytorch_model.bin:  25% 168M/681M [00:01<00:05, 87.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   0% 0.00/1.73G [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:   0% 0.00/167M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:  26% 178M/681M [00:01<00:05, 90.9MB/s]
#
#
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:01<00:00, 474kB/s]
#
#
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:01<00:00, 950kB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:   1% 10.5M/1.73G [00:00<00:22, 78.2MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:   6% 10.5M/167M [00:00<00:01, 79.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   1% 21.0M/1.73G [00:00<00:23, 72.3MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  13% 21.0M/167M [00:00<00:01, 77.8MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  19% 31.5M/167M [00:00<00:01, 87.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   2% 31.5M/1.73G [00:00<00:24, 70.2MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  25% 41.9M/167M [00:00<00:01, 89.5MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  31% 52.4M/167M [00:00<00:01, 92.3MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  38% 62.9M/167M [00:00<00:01, 90.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   2% 41.9M/1.73G [00:00<00:36, 46.3MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  44% 73.4M/167M [00:00<00:01, 92.0MB/s]
#
# Downloading (…)d75a/vae/config.json: 100% 612/612 [00:00<00:00, 110kB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:   3% 52.4M/1.73G [00:00<00:30, 55.6MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  50% 83.9M/167M [00:00<00:00, 92.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   4% 62.9M/1.73G [00:01<00:26, 63.5MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  56% 94.4M/167M [00:01<00:00, 90.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   4% 73.4M/1.73G [00:01<00:24, 69.0MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  63% 105M/167M [00:01<00:00, 89.9MB/s]
# Downloading pytorch_model.bin:  28% 189M/681M [00:03<00:21, 23.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   5% 83.9M/1.73G [00:01<00:23, 69.4MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  69% 115M/167M [00:01<00:00, 85.0MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  75% 126M/167M [00:01<00:00, 88.9MB/s]
# Downloading pytorch_model.bin:  29% 199M/681M [00:03<00:16, 29.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   6% 105M/1.73G [00:01<00:20, 80.8MB/s]
# Downloading pytorch_model.bin:  31% 210M/681M [00:03<00:13, 36.2MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  81% 136M/167M [00:01<00:00, 75.3MB/s]
# Downloading pytorch_model.bin:  32% 220M/681M [00:03<00:10, 43.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   7% 115M/1.73G [00:01<00:26, 61.5MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  94% 157M/167M [00:01<00:00, 89.4MB/s]
# Downloading pytorch_model.bin:  34% 231M/681M [00:03<00:09, 49.9MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin: 100% 167M/167M [00:01<00:00, 87.2MB/s]
#
# Downloading pytorch_model.bin:  35% 241M/681M [00:03<00:08, 52.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   8% 136M/1.73G [00:02<00:21, 73.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   8% 147M/1.73G [00:02<00:20, 76.7MB/s]
# Downloading pytorch_model.bin:  37% 252M/681M [00:04<00:08, 52.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   9% 157M/1.73G [00:02<00:21, 73.5MB/s]
# Downloading pytorch_model.bin:  38% 262M/681M [00:04<00:07, 57.4MB/s]
# Downloading pytorch_model.bin:  40% 273M/681M [00:04<00:06, 64.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  10% 178M/1.73G [00:02<00:19, 81.0MB/s]
# Downloading pytorch_model.bin:  42% 283M/681M [00:04<00:05, 69.1MB/s]
# Downloading pytorch_model.bin:  43% 294M/681M [00:04<00:05, 69.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  11% 189M/1.73G [00:02<00:22, 67.6MB/s]
# Downloading pytorch_model.bin:  45% 304M/681M [00:04<00:05, 73.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  12% 199M/1.73G [00:03<00:25, 59.0MB/s]
# Downloading pytorch_model.bin:  46% 315M/681M [00:05<00:05, 66.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  12% 210M/1.73G [00:03<00:24, 63.2MB/s]
# Downloading pytorch_model.bin:  48% 325M/681M [00:05<00:04, 71.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  13% 220M/1.73G [00:03<00:22, 67.8MB/s]
# Downloading pytorch_model.bin:  49% 336M/681M [00:05<00:05, 66.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  13% 231M/1.73G [00:03<00:21, 70.8MB/s]
# Downloading pytorch_model.bin:  51% 346M/681M [00:05<00:04, 69.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  14% 241M/1.73G [00:03<00:21, 70.8MB/s]
# Downloading pytorch_model.bin:  52% 357M/681M [00:05<00:04, 73.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  15% 252M/1.73G [00:03<00:21, 68.1MB/s]
# Downloading pytorch_model.bin:  54% 367M/681M [00:05<00:04, 76.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  15% 262M/1.73G [00:03<00:20, 72.2MB/s]
# Downloading pytorch_model.bin:  55% 377M/681M [00:05<00:04, 73.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  16% 273M/1.73G [00:04<00:21, 67.8MB/s]
# Downloading pytorch_model.bin:  57% 388M/681M [00:05<00:03, 75.2MB/s]
# Downloading pytorch_model.bin:  59% 398M/681M [00:06<00:03, 80.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  16% 283M/1.73G [00:04<00:22, 64.8MB/s]
# Downloading pytorch_model.bin:  60% 409M/681M [00:06<00:03, 83.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  17% 294M/1.73G [00:04<00:20, 68.5MB/s]
# Downloading pytorch_model.bin:  62% 419M/681M [00:06<00:03, 74.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  18% 304M/1.73G [00:04<00:20, 69.8MB/s]
# Downloading pytorch_model.bin:  63% 430M/681M [00:06<00:03, 75.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  18% 315M/1.73G [00:04<00:19, 71.2MB/s]
# Downloading pytorch_model.bin:  65% 440M/681M [00:06<00:03, 75.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  19% 325M/1.73G [00:04<00:20, 70.2MB/s]
# Downloading pytorch_model.bin:  66% 451M/681M [00:06<00:02, 80.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  19% 336M/1.73G [00:04<00:18, 74.4MB/s]
# Downloading pytorch_model.bin:  68% 461M/681M [00:06<00:02, 81.9MB/s]
# Downloading pytorch_model.bin:  69% 472M/681M [00:07<00:02, 82.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  20% 346M/1.73G [00:05<00:20, 66.9MB/s]
# Downloading pytorch_model.bin:  71% 482M/681M [00:07<00:02, 85.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  21% 357M/1.73G [00:05<00:19, 72.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  21% 367M/1.73G [00:05<00:18, 74.2MB/s]
# Downloading pytorch_model.bin:  72% 493M/681M [00:07<00:02, 67.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  22% 377M/1.73G [00:05<00:18, 72.7MB/s]
# Downloading pytorch_model.bin:  74% 503M/681M [00:07<00:02, 71.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  22% 388M/1.73G [00:05<00:17, 74.9MB/s]
# Downloading pytorch_model.bin:  75% 514M/681M [00:07<00:02, 74.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  23% 398M/1.73G [00:05<00:16, 78.6MB/s]
# Downloading pytorch_model.bin:  77% 524M/681M [00:07<00:02, 76.7MB/s]
# Downloading pytorch_model.bin:  79% 535M/681M [00:07<00:01, 80.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  24% 409M/1.73G [00:05<00:19, 68.3MB/s]
# Downloading pytorch_model.bin:  80% 545M/681M [00:07<00:01, 82.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  24% 419M/1.73G [00:06<00:20, 63.4MB/s]
# Downloading pytorch_model.bin:  82% 556M/681M [00:08<00:01, 82.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  25% 430M/1.73G [00:06<00:18, 70.0MB/s]
# Downloading pytorch_model.bin:  83% 566M/681M [00:08<00:01, 82.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  25% 440M/1.73G [00:06<00:17, 73.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  26% 451M/1.73G [00:06<00:16, 76.5MB/s]
# Downloading pytorch_model.bin:  85% 577M/681M [00:08<00:01, 69.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  27% 461M/1.73G [00:06<00:16, 78.1MB/s]
# Downloading pytorch_model.bin:  86% 587M/681M [00:08<00:01, 65.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  27% 472M/1.73G [00:06<00:15, 81.5MB/s]
# Downloading pytorch_model.bin:  88% 598M/681M [00:08<00:01, 71.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  28% 482M/1.73G [00:06<00:16, 74.0MB/s]
# Downloading pytorch_model.bin:  89% 608M/681M [00:08<00:00, 76.9MB/s]
# Downloading pytorch_model.bin:  91% 619M/681M [00:08<00:00, 81.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  28% 493M/1.73G [00:07<00:17, 71.4MB/s]
# Downloading pytorch_model.bin:  92% 629M/681M [00:09<00:00, 77.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  29% 503M/1.73G [00:07<00:16, 75.4MB/s]
# Downloading pytorch_model.bin:  94% 640M/681M [00:09<00:00, 79.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  30% 514M/1.73G [00:07<00:16, 76.0MB/s]
# Downloading pytorch_model.bin:  95% 650M/681M [00:09<00:00, 79.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  30% 524M/1.73G [00:07<00:15, 79.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  31% 535M/1.73G [00:07<00:14, 82.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  31% 545M/1.73G [00:07<00:14, 82.5MB/s]
# Downloading pytorch_model.bin:  97% 661M/681M [00:09<00:00, 61.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  32% 556M/1.73G [00:07<00:13, 85.2MB/s]
# Downloading pytorch_model.bin:  99% 671M/681M [00:09<00:00, 65.3MB/s]
# Downloading pytorch_model.bin: 100% 681M/681M [00:09<00:00, 68.7MB/s]
#
#
#
#
# Fetching 12 files:  33% 4/12 [00:10<00:24,  3.03s/it]
#
#
#
# Downloading (…)on_pytorch_model.bin:  33% 577M/1.73G [00:08<00:14, 78.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  34% 587M/1.73G [00:08<00:14, 78.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  35% 598M/1.73G [00:08<00:14, 80.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  35% 608M/1.73G [00:08<00:13, 81.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  36% 619M/1.73G [00:08<00:13, 84.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  36% 629M/1.73G [00:08<00:12, 86.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  37% 640M/1.73G [00:08<00:12, 86.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  38% 650M/1.73G [00:08<00:13, 78.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  38% 661M/1.73G [00:09<00:13, 80.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  39% 671M/1.73G [00:09<00:12, 82.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  39% 682M/1.73G [00:09<00:12, 85.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  40% 692M/1.73G [00:09<00:12, 86.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  41% 703M/1.73G [00:09<00:11, 88.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  41% 713M/1.73G [00:09<00:11, 90.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  42% 724M/1.73G [00:09<00:11, 89.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  42% 734M/1.73G [00:09<00:12, 77.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  43% 744M/1.73G [00:10<00:12, 79.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  44% 755M/1.73G [00:10<00:11, 83.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  44% 765M/1.73G [00:10<00:11, 83.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  45% 776M/1.73G [00:10<00:16, 58.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  45% 786M/1.73G [00:10<00:15, 62.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  46% 797M/1.73G [00:10<00:13, 68.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  47% 807M/1.73G [00:11<00:12, 74.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  47% 818M/1.73G [00:11<00:11, 78.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  48% 828M/1.73G [00:11<00:10, 82.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  48% 839M/1.73G [00:11<00:10, 84.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  49% 849M/1.73G [00:11<00:10, 86.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  50% 860M/1.73G [00:11<00:10, 86.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  50% 870M/1.73G [00:11<00:10, 85.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  51% 881M/1.73G [00:11<00:09, 87.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  51% 891M/1.73G [00:11<00:09, 89.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  52% 902M/1.73G [00:12<00:09, 90.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  53% 912M/1.73G [00:12<00:08, 92.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  53% 923M/1.73G [00:12<00:08, 90.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  54% 933M/1.73G [00:12<00:08, 89.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  54% 944M/1.73G [00:12<00:08, 89.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  55% 954M/1.73G [00:12<00:08, 90.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  56% 965M/1.73G [00:12<00:08, 90.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  56% 975M/1.73G [00:12<00:08, 90.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  57% 986M/1.73G [00:12<00:08, 91.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  58% 996M/1.73G [00:13<00:08, 90.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  58% 1.01G/1.73G [00:13<00:07, 91.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  59% 1.02G/1.73G [00:13<00:07, 91.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  59% 1.03G/1.73G [00:13<00:07, 92.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  60% 1.04G/1.73G [00:13<00:07, 91.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  61% 1.05G/1.73G [00:13<00:07, 89.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  61% 1.06G/1.73G [00:13<00:07, 91.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  62% 1.07G/1.73G [00:13<00:07, 92.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  62% 1.08G/1.73G [00:13<00:06, 93.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  63% 1.09G/1.73G [00:14<00:07, 90.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  64% 1.10G/1.73G [00:14<00:06, 92.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  64% 1.11G/1.73G [00:14<00:06, 92.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  65% 1.12G/1.73G [00:14<00:06, 93.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  65% 1.13G/1.73G [00:14<00:06, 88.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  66% 1.14G/1.73G [00:14<00:06, 89.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  67% 1.15G/1.73G [00:14<00:06, 91.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  67% 1.16G/1.73G [00:14<00:06, 91.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  68% 1.17G/1.73G [00:15<00:06, 92.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  68% 1.18G/1.73G [00:15<00:05, 92.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  69% 1.20G/1.73G [00:15<00:05, 93.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  70% 1.21G/1.73G [00:15<00:05, 91.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  70% 1.22G/1.73G [00:15<00:05, 92.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  71% 1.23G/1.73G [00:15<00:05, 93.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  71% 1.24G/1.73G [00:15<00:05, 93.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  72% 1.25G/1.73G [00:15<00:05, 91.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  73% 1.26G/1.73G [00:15<00:05, 92.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  73% 1.27G/1.73G [00:16<00:04, 93.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  74% 1.28G/1.73G [00:16<00:04, 93.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  74% 1.29G/1.73G [00:16<00:04, 92.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  75% 1.30G/1.73G [00:16<00:04, 91.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  76% 1.31G/1.73G [00:16<00:04, 92.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  76% 1.32G/1.73G [00:16<00:04, 91.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  77% 1.33G/1.73G [00:16<00:04, 86.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  77% 1.34G/1.73G [00:16<00:04, 88.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  78% 1.35G/1.73G [00:16<00:04, 87.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  79% 1.36G/1.73G [00:17<00:04, 89.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  79% 1.37G/1.73G [00:17<00:03, 90.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  80% 1.38G/1.73G [00:17<00:03, 90.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  81% 1.39G/1.73G [00:17<00:03, 92.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  81% 1.41G/1.73G [00:17<00:03, 92.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  82% 1.42G/1.73G [00:17<00:03, 91.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  82% 1.43G/1.73G [00:17<00:03, 88.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  83% 1.44G/1.73G [00:17<00:03, 89.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  84% 1.45G/1.73G [00:18<00:03, 87.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  84% 1.46G/1.73G [00:18<00:03, 89.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  85% 1.47G/1.73G [00:18<00:02, 90.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  85% 1.48G/1.73G [00:18<00:02, 91.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  86% 1.49G/1.73G [00:18<00:02, 92.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  87% 1.50G/1.73G [00:18<00:02, 81.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  87% 1.51G/1.73G [00:18<00:02, 77.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  88% 1.52G/1.73G [00:18<00:02, 81.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  88% 1.53G/1.73G [00:19<00:02, 82.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  89% 1.54G/1.73G [00:19<00:02, 83.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  90% 1.55G/1.73G [00:19<00:02, 86.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  90% 1.56G/1.73G [00:19<00:01, 87.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  91% 1.57G/1.73G [00:19<00:01, 88.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  91% 1.58G/1.73G [00:19<00:01, 90.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  92% 1.59G/1.73G [00:19<00:01, 91.7MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  93% 1.60G/1.73G [00:19<00:01, 89.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  93% 1.61G/1.73G [00:19<00:01, 88.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  94% 1.63G/1.73G [00:20<00:01, 88.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  94% 1.64G/1.73G [00:20<00:01, 88.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  95% 1.65G/1.73G [00:20<00:00, 88.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  96% 1.66G/1.73G [00:20<00:00, 88.5MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  96% 1.67G/1.73G [00:20<00:00, 90.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  97% 1.68G/1.73G [00:20<00:00, 92.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  97% 1.69G/1.73G [00:20<00:00, 91.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  98% 1.70G/1.73G [00:20<00:00, 91.6MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  99% 1.71G/1.73G [00:21<00:00, 92.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  99% 1.72G/1.73G [00:21<00:00, 93.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin: 100% 1.73G/1.73G [00:21<00:00, 80.9MB/s]
# Fetching 12 files: 100% 12/12 [00:24<00:00,  2.03s/it]
# 04/04/2023 18:50:11 - INFO - __main__ - Number of class images to sample: 50.
# Generating class images: 100% 13/13 [06:57<00:00, 32.09s/it]
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:105: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.28.0.1'), PosixPath('8013'), PosixPath('http')}
#   warn(
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('--listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https'), PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-t4-s-3j0z63jtn4zop --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true')}
#   warn(
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//ipykernel.pylab.backend_inline')}
#   warn(
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.9/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# /usr/local/lib/python3.9/dist-packages/diffusers/configuration_utils.py:203: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Downloading (…)cheduler_config.json: 100% 345/345 [00:00<00:00, 119kB/s]
# Caching latents: 100% 50/50 [00:10<00:00,  4.70it/s]
# 04/04/2023 18:57:46 - INFO - __main__ - ***** Running training *****
# 04/04/2023 18:57:46 - INFO - __main__ -   Num examples = 50
# 04/04/2023 18:57:46 - INFO - __main__ -   Num batches each epoch = 50
# 04/04/2023 18:57:46 - INFO - __main__ -   Num Epochs = 16
# 04/04/2023 18:57:46 - INFO - __main__ -   Instantaneous batch size per device = 1
# 04/04/2023 18:57:46 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 04/04/2023 18:57:46 - INFO - __main__ -   Gradient Accumulation steps = 1
# 04/04/2023 18:57:46 - INFO - __main__ -   Total optimization steps = 800
# Steps:   0% 0/800 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/xformers/ops/fmha/flash.py:338: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   and inp.query.storage().data_ptr() == inp.key.storage().data_ptr()
# Steps: 100% 800/800 [09:53<00:00,  1.35it/s, loss=0.588, lr=1e-6]text_encoder/model.safetensors not found
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:13<00:40, 13.66s/it]
# Generating samples:  50% 2/4 [00:22<00:21, 10.55s/it]
# Generating samples:  75% 3/4 [00:30<00:09,  9.62s/it]
# Generating samples: 100% 4/4 [00:38<00:00,  9.74s/it]
# [*] Weights saved at /content/stable_diffusion_weights/zwx/800
# Steps: 100% 800/800 [10:58<00:00,  1.22it/s, loss=0.588, lr=1e-6]

# %%
#@markdown Specify the weights directory to use (leave blank for latest)
WEIGHTS_DIR = "" #@param {type:"string"}
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")
# Out:
# [*] WEIGHTS_DIR=/content/stable_diffusion_weights/zwx/800

# %%
#@markdown Run to generate a grid of preview images from the last saved weights.
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

weights_folder = OUTPUT_DIR
folders = sorted([f for f in os.listdir(weights_folder) if f != "0"], key=lambda x: int(x))

row = len(folders)
col = len(os.listdir(os.path.join(weights_folder, folders[0], "samples")))
scale = 4
fig, axes = plt.subplots(row, col, figsize=(col*scale, row*scale), gridspec_kw={'hspace': 0, 'wspace': 0})

for i, folder in enumerate(folders):
    folder_path = os.path.join(weights_folder, folder)
    image_folder = os.path.join(folder_path, "samples")
    images = [f for f in os.listdir(image_folder)]
    for j, image in enumerate(images):
        if row == 1:
            currAxes = axes[j]
        else:
            currAxes = axes[i, j]
        if i == 0:
            currAxes.set_title(f"Image {j}")
        if j == 0:
            currAxes.text(-0.1, 0.5, folder, rotation=0, va='center', ha='center', transform=currAxes.transAxes)
        image_path = os.path.join(image_folder, image)
        img = mpimg.imread(image_path)
        currAxes.imshow(img, cmap='gray')
        currAxes.axis('off')
        
plt.tight_layout()
plt.savefig('grid.png', dpi=72)

# %% [markdown]
# ## Convert weights to ckpt to use in web UIs like AUTOMATIC1111.

# %%
#@markdown Run conversion.
ckpt_path = WEIGHTS_DIR + "/model.ckpt"

half_arg = ""
#@markdown  Whether to convert to fp16, takes half the space (2GB).
fp16 = True #@param {type: "boolean"}
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $WEIGHTS_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")

# %% [markdown]
# ## Inference

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

pipe = StableDiffusionPipeline.from_pretrained(model_path, safety_checker=None, torch_dtype=torch.float16).to("cuda")
pipe.scheduler = DDIMScheduler.from_config(pipe.scheduler.config)
pipe.enable_xformers_memory_efficient_attention()
g_cuda = None

# %%
#@markdown Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = 52362 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = "photo of ukj person child in a bucket" #@param {type:"string"}
negative_prompt = "" #@param {type:"string"}
num_samples = 4 #@param {type:"number"}
guidance_scale = 16 #@param {type:"number"}
num_inference_steps = 60 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}


with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F99EF228FA0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F9A025D40A0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F9A025D4B20>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F9A03810DF0>

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, negative_prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
                prompt, height=int(height), width=int(width),
                negative_prompt=negative_prompt,
                num_images_per_prompt=int(num_samples),
                num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
                generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of zwx dog in a bucket")
            negative_prompt = gr.Textbox(label="Negative Prompt", value="")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=24)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, negative_prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)

# %%
#@title (Optional) Delete diffuser and old weights and only keep the ckpt to free up drive space.

#@markdown [ ! ] Caution, Only execute if you are sure u want to delete the diffuser format weights and only use the ckpt.
import shutil
from glob import glob
import os
for f in glob(OUTPUT_DIR+os.sep+"*"):
    if f != WEIGHTS_DIR:
        shutil.rmtree(f)
        print("Deleted", f)
for f in glob(WEIGHTS_DIR+"/*"):
    if not f.endswith(".ckpt") or not f.endswith(".json"):
        try:
            shutil.rmtree(f)
        except NotADirectoryError:
            continue
        print("Deleted", f)

# %%
#@title Free runtime memory
exit()
